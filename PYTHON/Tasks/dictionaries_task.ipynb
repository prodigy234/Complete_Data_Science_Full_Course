# %% [markdown]
# # Task 1: Create a Dictionary
#
# ## Question
#
# `Create a dictionary called student with the following information:`
#
# - Name: John
#
# - Age: 22
#
# - Course: Data Science
#
# - Country: Nigeria

# %% [markdown]
# # Task 2
#
# ## Access Dictionary Values
#
# ```Question
#
# Given the dictionary below:
#
# student = {
#     "name": "John",
#     "age": 22,
#     "course": "Python"
# }
#
# Print:
#
# - Name
#
# - Age
# ```

# %% [markdown]
# # Task 3: Using get()
#
# ## Question
#
# ```Using the dictionary below:
#
# student = {
#     "name": "John",
#     "age": 22
# }
#
# - Print the student's course using get().
#
# - If the key doesn't exist, return:
#
# - Course Not Found
# ```
