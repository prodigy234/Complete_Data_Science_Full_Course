# %% [markdown]
# Using the clean_power_bi_dataset
#
# WHAT YOU NOW HAVE (PROPER STAR SCHEMA)
#
# FACT TABLE
#
# Sales Table
#
# OrderID
# Date
# CustomerID
# ProductID
# Quantity
# Sales Amount
# Profit
#
# DIMENSION TABLES
#
# Customers Table
#
# CustomerID
# Customer Name
# Region
# Age
# Segment
#
# Products Table
#
# ProductID
# Product Name
# Category
# Price
#
# STEP 1: DATA MODELLING (IN POWER BI)
#
# After loading:
#
# Create Relationships:
# Sales[CustomerID] → Customers[CustomerID]
#
# Sales[ProductID] → Products[ProductID]
#
# Cardinality: Many-to-One (*:1)
# Cross filter: Single
#
# STEP 2: CREATE DAX MEASURES
#
# Create these FIRST:
#
# Total Sales
# Total Sales = SUM(Sales[Sales Amount])
#
# Total Profit
# Total Profit = SUM(Sales[Profit])
#
# Total Quantity
# Total Quantity = SUM(Sales[Quantity])
#
# Profit Margin
# Profit Margin = DIVIDE([Total Profit], [Total Sales])
#
# Total Customers
# Total Customers = DISTINCTCOUNT(Customers[CustomerID])
#
# STEP 3: DASHBOARD VISUALS (VERY IMPORTANT)
#
#
#
# 1. LINE CHART (Sales Trend Over Time)
# Use:
# X-Axis: Date
# Y-Axis: Total Sales
#
# Insight:
#
# Shows growth trend over time
#
# 2. BAR CHART (Sales by Region)
# Use:
# X-Axis: Region
# Y-Axis: Total Sales
# Legend (optional): Segment
#
# Insight:
#
# Which region generates the most revenue
#
# 3. COLUMN CHART (Sales by Product)
# Use:
# X-Axis: Product Name
# Y-Axis: Total Sales
#
# Insight:
#
# Best-selling products
#
# 4. PIE CHART (Sales by Category)
# Use:
# Legend: Category
# Values: Total Sales
#
# Insight:
#
# Contribution of each category
#
# 5. STACKED BAR CHART (Segment Analysis)
# Use:
# X-Axis: Region
# Y-Axis: Total Sales
# Legend: Segment
#
# Insight:
#
# Customer segment distribution per region
#
# 6. TABLE VISUAL (Detailed View)
# Columns:
# Customer Name
# Product Name
# Sales Amount
# Profit
#
# Insight:
#
# Transaction-level analysis
#
# 7. KPI CARDS (VERY IMPORTANT)
#
# Create Cards for:
#
# Total Sales
# Total Profit
# Total Customers
# Profit Margin
#
# 8. CLUSTERED COLUMN CHART (Sales vs Profit)
# Use:
# X-Axis: Product Name
# Values:
# Total Sales
# Total Profit
#
# Insight:
#
# Compare revenue vs profitability
#
# 9. MAP VISUAL (If enabled)
# Use:
# Location: Region
# Size: Total Sales
#
# Insight:
#
# Geographic performance
#
# 10. SLICERS (INTERACTIVITY)
#
# Add slicers for:
#
# Date
# Region
# Product Name
# Segment

# %% [markdown]
# ADVANCED VISUAL
#
# Sales by Age Group
#
# Step:
#
# Create column:
#
# Age Group =
# IF(Customers[Age] < 30, "Young",
# IF(Customers[Age] < 50, "Adult", "Senior"))
#
# Chart:
# X-Axis → Age Group
# Y-Axis → Total Sales

# %% [markdown]
# STORYBOARD FOR YOUR DASHBOARD
#
# Top Section:
# KPI Cards
#
# Middle:
# Sales Trend (Line Chart)
#
# Bottom:
# Region, Product, Segment charts
